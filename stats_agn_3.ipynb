# %% [markdown]
# ques 1 What is a random variable in probability theory?
#
#  A random variable is a fundamental concept in probability theory. It's essentially a variable that takes on different values based on the outcome of a random experiment or process. The value that the random variable takes is determined by chance, and these values can be discrete or continuous, depending on the type of random variable.

# %% [markdown]
#  ques 2 What are the types of random variables?
#
# 1. Discrete Random Variables:
#
# * Definition: A discrete random variable takes on a finite or countably infinite set of distinct values.
#
# * Examples: The number of heads when flipping a coin multiple times (e.g., 0, 1, 2, ... heads).
#
# The number of people living in a city  (e.g., 250, 100, 500.....).
#
#
# 2. Continuous Random Variables:
#
# * Definition: A continuous random variable can take on any value within a given range or interval (this range can be finite or infinite). The possible outcomes are uncountably infinite.
#
# * Examples:  The height of a person (e.g., 170.5 cm, 170.55 cm, 170.555 cm, etc.).
#
# The temperature in a city on a given day (which could vary continuously from a very small value to a very large one).

# %% [markdown]
# ques 3 What is the difference between discrete and continuous distributions?
#
# Differences between discrete and continuous distribution :
#
# **1. Nature of Random Variable:**
#
# Discrete Distribution: Describes random variables that can only take specific, distinct values. These values are countable (either finite or countably infinite).
#
# EXAMPLE :  Number of heads in 10 coin flips, number of cars passing a checkpoint in an hour, number of students in a class.
#
# Continuous Distribution: Describes random variables that can take any value within a certain range or interval. These values are uncountably infinite.
#
# EXAMPLE:  Height of a person, time it takes to complete a task, temperature at a given time.
#
# 2. **Probability Functions:**
# Discrete Distribution: The probability function is a probability mass function (PMF), which gives the probability of each distinct outcome.
#
# Continuous Distribution: The probability function is a probability density function (PDF). The PDF gives the relative likelihood of the random variable taking a value in a specific interval.
#
# 3. **Probability of Single Points:**
#
# Discrete Distribution: The probability of a random variable taking a particular value is non-zero.
#
# Continuous Distribution: The probability of the random variable taking exactly any particular value is always zero. Probabilities are assigned to intervals or ranges.

# %% [markdown]
# ques 4 What are probability distribution functions (PDF)?
#
# The probability distribution functions (PDF) describes the relative likelihood of a continuous random variable taking a specific value. However, for continuous variables, the probability of the variable taking an exact value is always zero (since there are infinite possible values). Instead, probabilities are calculated over intervals or ranges.

# %% [markdown]
# ques 5 How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#
# 1. **Define:**
#
# CDF gives the cumulative probability that a random variable takes a value less than or equal to x.
#
# PDF gives the probability density at a specific point or interval for continuous random variables (or the probability mass for discrete variables).
#
# 2. **Range	:**
#
# CDF IS Ranges from 0 to 1.
#
# The PDF is non-negative, but its values can exceed 1 (for continuous variables).
#
# 3. **Type of Variables:**
#
# CDF works for both discrete and continuous random variables.
#
# PDF works for discrete (via PMF) or continuous random variables.

# %% [markdown]
# ques 6 What is a discrete uniform distribution?
#
# A Discrete Uniform Distribution is one of the simplest types of discrete probability distributions. It is a distribution where a random variable can take on a finite number of distinct values, and each of these values is equally likely to occur. In other words, all outcomes in the sample space have the same probability.

# %% [markdown]
# ques 7 What are the key properties of a Bernoulli distribution?
#
# The Bernoulli Distribution is one of the simplest and most fundamental probability distributions in statistics and probability theory. It describes the outcome of a single trial (or experiment) that has only two possible outcomes: success or failure
#
# key properties of a Bernoulli distribution:
# 1. Two Possible Outcomes: The Bernoulli distribution represents a random variable 𝑋X that can take only two possible values: 0 (failure) or 1 (success).
#
# 2. Probability Mass Function (PMF): The PMF of a Bernoulli-distributed random variable X is given by: 𝑃(𝑋=𝑥)={𝑝 , if 𝑥=1 or 1−p if 𝑥=0}
#
# 3. The mean or expected value E[X] of a Bernoulli distribution is simply the probability of success : E[X]=p
#
# 4. The variance Var(X) of a Bernoulli distribution is given by : Var(X)=𝑝(1−𝑝)
#
# 5. The standard deviation σ is the square root of the variance:𝜎= UNDER ROOT 𝑝(1−𝑝)
# ​

# %% [markdown]
# ques 8 What is the binomial distribution, and how is it used in probability?
#
# The Binomial Distribution is one of the most widely used discrete probability distributions in statistics. It describes the number of successes in a fixed number of independent trials of a Bernoulli experiment (where each trial has only two possible outcomes, such as success or failure).
#
# The binomial distribution is essential in probability theory because it provides a way to model scenarios where there are multiple independent trials, each with two possible outcomes (success or failure). It is widely used in applications ranging from quality control and surveys to medical studies and gambling. By using the binomial probability formula, you can calculate the likelihood of different numbers of successes across trials, making it an invaluable tool in statistical analysis and decision-making.

# %% [markdown]
# ques 9 What is the Poisson distribution and where is it applied?
#
# The Poisson distribution is a discrete probability distribution that models the number of events occurring in a fixed interval of time or space, given that the events happen with a known constant rate and independently of each other. It is often used to model rare events or events that happen infrequently within a given time frame or region.
#
#  It is commonly applied in fields like telecommunications, queueing theory, medicine, astronomy, and traffic management, among others. By understanding its properties and applications, you can effectively model situations where events occur independently and at a constant average rate.

# %% [markdown]
# ques 10 What is a continuous uniform distribution?
#
# A continuous uniform distribution is a probability distribution in which all outcomes in a given continuous range are equally likely to occur. Unlike discrete distributions (such as the binomial or Poisson distributions), a continuous uniform distribution is used to model situations where the variable of interest can take any value within a specified interval, and the probability of the variable falling anywhere within that interval is the same.

# %% [markdown]
# ques 11 What are the characteristics of a normal distribution ?
#
# The normal distribution is a continuous, symmetric probability distribution with a bell-shaped curve.
#
#  Its key characteristics are:
#
# * The normal distribution has a symmetric bell-shaped curve. This means the left side of the curve is a mirror image of the right side.
#
# * The mean, median, and mode are all equal and located at the center of the distribution.
#
# * It is symmetric, with the tails extending infinitely in both directions.
#
# * It is fully defined by two parameters: the mean 𝜇 (location) and the standard deviation σ (spread).
#
# * The Empirical Rule (68-95-99.7 Rule) describes the percentage of data within 1, 2, and 3 standard deviations of the mean.
#
# * The standard normal distribution is a special case with a mean of 0 and a standard deviation of 1.

# %% [markdown]
# ques 12 What is the standard normal distribution, and why is it important?
#
# The standard normal distribution is a special case of the normal distribution, a type of probability distribution that is symmetric and bell-shaped.
#
# importance of standard normal distribution :
#
#
# 1. **Central Limit Theorem:** The standard normal distribution is crucial in statistics because of the Central Limit Theorem (CLT). According to the CLT, the distribution of the sum (or average) of a large number of independent, identically distributed random variables will tend to approximate a normal distribution, regardless of the shape of the original distribution. This allows for making statistical inferences about the population using the normal distribution, even if the data are not originally normally distributed.
#
# 2. **Standardization:** Many real-world data sets can be transformed into the standard normal form by standardization (also called z-scoring). This involves converting values from any normal distribution with a mean μ and standard deviation σ into values with a mean of 0 and a standard deviation of 1 using the formula:𝑧=𝑥−𝜇 / 𝜎
#
# 3. **Ease of Calculation:** Once data are transformed into the standard normal distribution, we can use standard statistical techniques and tables to calculate probabilities, critical values, and make predictions. For example, in hypothesis testing, the z-test relies on the standard normal distribution to determine how far a sample mean is from the population mean in terms of standard deviations.
#
# 4. **Widely Applicable:** The standard normal distribution is used in a wide range of fields, including finance, science, engineering, and psychology, to model phenomena that exhibit variability and follow a roughly symmetric distribution, such as measurement error

# %% [markdown]
# ques 13  What is the Central Limit Theorem (CLT), and why is it critical in statistics ?
#
# The Central Limit Theorem (CLT) is a fundamental concept in statistics that states that "The distribution of the sum (or average) of a large number of independent, identically distributed random variables will approximate a normal distribution, regardless of the original distribution of the variables."
#
# he Central Limit Theorem is critical in statistics because it enables the use of normal distribution-based techniques to analyze and infer population parameters from sample data. It simplifies complex problems, ensures robustness in statistical methods, and makes it possible to apply standard statistical tools in real-world situations, regardless of the underlying data distribution.

# %% [markdown]
# ques 14 How does the Central Limit Theorem relate to the normal distribution?
#
# The Central Limit Theorem essentially makes the normal distribution a universal tool in statistics by guaranteeing that the sampling distribution of the sample mean will approach normality as the sample size increases, regardless of the shape of the original population distribution. This relationship allows statisticians to use normal distribution-based techniques (like z-tests, confidence intervals, etc.) to draw inferences from data, even when the population distribution is not normal.

# %% [markdown]
# ques 15  What is the application of Z statistics in hypothesis testing?
#
#  The application of Z statistics in hypothesis testing:
#
# 1. One-Sample Z-Test (For Mean): A one-sample Z-test is used to determine if the mean of a sample is significantly different from a known population mean when the population standard deviation is known.
#
# Null Hypothesis (H₀): The sample mean is equal to the population mean (𝜇0).
#
# Alternative Hypothesis (H₁): The sample mean is not equal to the population mean (𝜇0) (or greater or smaller, depending on the directionality)
#
# 2. Two-Sample Z-Test (For Means): A two-sample Z-test is used to compare the means of two independent samples to see if they are significantly different, assuming the population variances are known or the sample size is large enough for the CLT to apply.
#
# Null Hypothesis (H₀): The two sample means are equal (𝜇1=𝜇2).
#
# Alternative Hypothesis (H₁): The two sample means are not equal( 𝜇1≠𝜇2 ).
#
# 3. Z-Test for Proportions: A Z-test for proportions is used to test whether the proportion of successes in a sample is different from a known population proportion or if there’s a difference between the proportions of two independent samples.
#
# Null Hypothesis (H₀): The sample proportion is equal to the population proportion (𝑝0).
#
# Alternative Hypothesis (H₁): The sample proportion is not equal to the population proportion (𝑝0)

# %% [markdown]
# ques 16  How do you calculate a Z-score, and what does it represent?
#
# A Z-score (also called a standard score or Z-value) measures how many standard deviations a specific data point (or observation) is away from the mean of the distribution. It helps to standardize data, making it easier to compare values from different distributions.
#
# Steps for Calculating a Z-Score:
#
# 1. Identify the value X: This is the specific data point or observation you're interested in.
#
# 2. Determine the mean 𝜇μ: This is the average of the dataset or population from which X is drawn.
#
# 3. Calculate the standard deviation σ: The standard deviation tells you how spread out the data is around the mean.
#
# 4. Plug values into the Z-score formula: Subtract the mean from the value X, and then divide by the standard deviation.
#
# The Z-score represents the number of standard deviations a data point is away from the mean. It is used for comparing individual data points to the mean of a distribution, identifying outliers, standardizing data, and calculating probabilities. A Z-score allows you to understand how extreme or typical a value is within the context of the data set.

# %% [markdown]
# ques 17 What are point estimates and interval estimates in statistics?
#
# **Point Estimate:**
#
# A point estimate is a single value that is used to estimate an unknown population parameter. It is derived from sample data and serves as the "best guess" or most likely value for the parameter.
#
# **Interval Estimate:**
#
# An interval estimate provides a range of values, rather than a single point, within which the population parameter is expected to lie. This estimate includes a margin of error and a confidence level to indicate how certain we are that the true parameter is within the range

# %% [markdown]
# ques 18 What is the significance of confidence intervals in statistical analysis?
#
# A confidence interval (CI) is a crucial concept in statistical analysis, providing a range of values that is likely to contain an unknown population parameter (such as a population mean, proportion, or difference between groups). The confidence interval not only gives an estimate of where the parameter lies but also quantifies the uncertainty associated with that estimate.
#
# Confidence intervals are crucial because they give more than just a single estimate—they provide a range that reflects the uncertainty and variability inherent in statistical estimates. They are valuable for making informed decisions, assessing risks, comparing groups, and ensuring statistical significance. By understanding and interpreting confidence intervals, you gain a deeper understanding of the reliability of your estimates and make more robust conclusions based on your data.

# %% [markdown]
# ques 19 What is the relationship between a Z-score and a confidence interval?
#
# * A Z-score is a standard measure used to determine how far a sample statistic (like the sample mean) is from the population parameter, expressed in terms of standard deviations.
#
# * A confidence interval uses the Z-score to define a range of plausible values for a population parameter, based on sample data, and a given confidence level.
#
# * The Z-score is used to calculate the margin of error for the confidence interval, and it directly reflects the confidence level. A higher confidence level corresponds to a larger Z-score and a wider confidence interval, whereas a lower confidence level corresponds to a smaller Z-score and a narrower confidence interval.

# %% [markdown]
# ques 20 How are Z-scores used to compare different distributions?
#
# Z-scores are a powerful tool for comparing data points from different distributions, especially when those distributions may have different scales, means, or standard deviations. By standardizing the data, Z-scores allow for direct comparisons, even if the original distributions differ in their units or variability.
#
# * Z-scores provide a way to compare data points from different distributions by transforming them into a common scale (mean = 0, standard deviation = 1).
#
# * They show how "unusual" or "typical" a data point is relative to its distribution.
#
# * Z-scores standardize distributions, helping to normalize different datasets for comparison.

# %% [markdown]
# ques 21 What are the assumptions for applying the Central Limit Theorem?
#
# For the Central Limit Theorem to apply, the following assumptions should be met:
#
# * Independence of observations.
#
# * Large sample size (typically n ≥ 30), with larger samples needed if the population distribution is highly skewed or has outliers.
#
# * Random sampling to ensure the sample is representative of the population.
#
# * Finite variance in the population.

# %% [markdown]
# ques 22 What is the concept of expected value in a probability distribution?
#
# The expected value (also called the mean or mathematical expectation) is a key concept in probability theory and statistics. It provides a weighted average of all possible values that a random variable can take, where each value is weighted by its probability of occurring. The expected value represents the long-run average or center of the distribution and is a measure of the "center" of a probability distribution.

# %% [markdown]
# ques 23 How does a probability distribution relate to the expected outcome of a random variable?
#
# A probability distribution describes the likelihood of different possible outcomes for a random variable, while the expected value (or mean) represents the average outcome of that random variable, weighted by the probabilities of each possible outcome. The relationship between a probability distribution and the expected outcome of a random variable is that the expected value is essentially a weighted average of all possible values the random variable can take, based on their probabilities.
#
# Relationship Between a Probability Distribution and Expected Outcome
# Probability Distribution:
#
# 1. A probability distribution shows all possible values a random variable can take and their associated probabilities. It can be:
#
# Discrete (for random variables that take distinct, separate values, such as the result of rolling a die).
#
# Continuous (for random variables that take any value within a continuous range, such as a person's height or the temperature on a given day).
#
# 2. Expected Value:
#
# The expected value of a random variable is the long-term average of the outcomes, weighted by their respective probabilities. In other words, it's the "center" or "balance point" of the distribution.
#
# The expected value tells you what the mean outcome would be if the random experiment or process were repeated many times.

# %% [markdown]
# # **pratical**

# %%
# ques 1 Write a Python program to generate a random variable and display its value

import random

# Generate a random integer between 1 and 100
random_variable = random.randint(1, 100)

# Display the random value
print("The random value is:", random_variable)
# Out:
# The random value is: 68

# %%
#ques 2 Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)

import numpy as np
import matplotlib.pyplot as plt

low = 1
high = 6
size = 1000
samples = np.random.choice(range(low, high+1), size=size)
values, counts = np.unique(samples, return_counts=True)
pmf = counts / size
plt.bar(values, pmf, width=0.8, align='center', color='skyblue', edgecolor='black')
plt.title("Probability Mass Function of a Discrete Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Probability")
plt.xticks(values)
plt.grid(True)
plt.show()

# %%
# ques 3 Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution

def bernoulli_pdf(x, p):
    """
    Calculate the Probability Distribution Function (PDF) of a Bernoulli distribution.

    Parameters:
    x (int): The outcome (0 or 1).
    p (float): The probability of success (0 <= p <= 1).

    Returns:
    float: The probability of the outcome x.
    """
    if x not in [0, 1]:
        raise ValueError("x must be either 0 or 1")

    if p < 0 or p > 1:
        raise ValueError("p must be between 0 and 1 inclusive")

    if x == 1:
        return p
    else:
        return 1 - p
p = 0.7
x1 = 1
x0 = 0
print(f"P(X = 1) = {bernoulli_pdf(x1, p)}")
print(f"P(X = 0) = {bernoulli_pdf(x0, p)}")
# Out:
# P(X = 1) = 0.7
# P(X = 0) = 0.30000000000000004

# %%
# ques 4 Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram

n = 10
p = 0.5
size = 1000
binomial_samples = np.random.binomial(n, p, size)
plt.hist(binomial_samples, bins=range(n+2), edgecolor='black', density=True, alpha=0.7, color='skyblue')

plt.title(f"Histogram of Binomial Distribution (n={n}, p={p})")
plt.xlabel("Number of successes")
plt.ylabel("Probability")
plt.xticks(range(n+1))
plt.grid(True)
plt.show()

# %%
# ques 5  Create a Poisson distribution and visualize it using Python


lambda_ = 5
size = 1000
poisson_samples = np.random.poisson(lambda_, size)
plt.hist(poisson_samples, bins=range(min(poisson_samples), max(poisson_samples) + 1), edgecolor='black', density=True, alpha=0.7, color='skyblue')
plt.title(f"Poisson Distribution (λ={lambda_})")
plt.xlabel("Number of Events")
plt.ylabel("Probability")
plt.xticks(range(min(poisson_samples), max(poisson_samples) + 1))
plt.grid(True)
plt.show()

# %%
#ques 6 Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution

a = 1
b = 6
size = 1000
samples = np.random.choice(range(a, b + 1), size=size)
values, counts = np.unique(samples, return_counts=True)
probabilities = counts / size
cdf = np.cumsum(probabilities)
plt.step(values, cdf, where='post', color='skyblue', linestyle='-', linewidth=2)
plt.title(f"Cumulative Distribution Function (CDF) of Discrete Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Cumulative Probability")
plt.xticks(values)
plt.grid(True)
plt.show()

# %%
# ques 7 Generate a continuous uniform distribution using NumPy and visualize it

low = 0
high = 10
size = 10000
uniform_samples = np.random.uniform(low, high, size)
plt.hist(uniform_samples, bins=30, edgecolor='black', density=True, alpha=0.7, color='skyblue')
plt.title(f"Continuous Uniform Distribution\n(low={low}, high={high})")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# ques 8 Simulate data from a normal distribution and plot its histogram

mean = 0
std = 1
size = 10000
normal_samples = np.random.normal(mean, std, size)
plt.hist(normal_samples, bins=30, edgecolor='black', density=True, alpha=0.7, color='skyblue')
plt.title(f"Histogram of Normal Distribution\n(mean={mean}, std={std})")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# ques 9 Write a Python function to calculate Z-scores from a dataset and plot them


def calculate_z_scores(data):
    """
    Calculate the Z-scores for a given dataset.

    Parameters:
    data (array-like): The dataset from which to calculate Z-scores.

    Returns:
    array: The Z-scores for each element in the dataset.
    """

    mean = np.mean(data)
    std_dev = np.std(data)
    z_scores = (data - mean) / std_dev

    return z_scores
data = np.random.normal(0, 1, 1000)
z_scores = calculate_z_scores(data)
plt.figure(figsize=(8, 6))
plt.hist(z_scores, bins=30, edgecolor='black', color='skyblue', alpha=0.7, density=True)
plt.title("Histogram of Z-scores")
plt.xlabel("Z-score")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# ques 10 Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.


def central_limit_theorem(n_samples, sample_size, distribution, *params):
    """
    Demonstrates the Central Limit Theorem using the specified distribution.

    Parameters:
    - n_samples: Number of random samples to draw
    - sample_size: Size of each sample
    - distribution: The distribution to sample from (e.g., np.random.exponential)
    - *params: Additional parameters for the distribution (like scale for exponential)

    Returns:
    - sample_means: List of means of the samples
    """
    sample_means = []
    for _ in range(n_samples):
        sample = distribution(*params, size=sample_size)
        sample_mean = np.mean(sample)
        sample_means.append(sample_mean)

    return sample_means
n_samples = 1000
sample_size = 50
distribution = np.random.exponential
lambda_param = 1
sample_means = central_limit_theorem(n_samples, sample_size, distribution, lambda_param)
plt.hist(sample_means, bins=30, edgecolor='black', alpha=0.7, color='skyblue', density=True)
plt.title(f"Central Limit Theorem - Sample Means from Exponential Distribution\nSample Size={sample_size}, n_samples={n_samples}")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# ques 11 Simulate multiple samples from a normal distribution and verify the Central Limit Theorem

import numpy as np
import matplotlib.pyplot as plt

def central_limit_theorem_normal(n_samples, sample_size, mean, std_dev):
    """
    Demonstrates the Central Limit Theorem using a normal distribution.

    Parameters:
    - n_samples: Number of samples to draw
    - sample_size: Size of each sample
    - mean: Mean of the normal distribution
    - std_dev: Standard deviation of the normal distribution

    Returns:
    - sample_means: List of means of the samples
    """
    sample_means = []
    for _ in range(n_samples):
        sample = np.random.normal(mean, std_dev, sample_size)
        sample_mean = np.mean(sample)
        sample_means.append(sample_mean)

    return sample_means
mean = 50
std_dev = 10
n_samples = 1000
sample_size = 50
sample_means = central_limit_theorem_normal(n_samples, sample_size, mean, std_dev)
plt.hist(sample_means, bins=30, edgecolor='black', alpha=0.7, color='skyblue', density=True)
plt.title(f"Central Limit Theorem - Sample Means from Normal Distribution\nSample Size={sample_size}, n_samples={n_samples}")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# ques 12 Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)

from scipy.stats import norm
def plot_standard_normal_distribution():
    x = np.linspace(-5, 5, 1000)
    pdf = norm.pdf(x, loc=0, scale=1)
    plt.plot(x, pdf, label="Standard Normal Distribution", color='blue', linewidth=2)
    plt.title("Standard Normal Distribution (mean=0, std=1)")
    plt.xlabel("x")
    plt.ylabel("Probability Density")
    plt.grid(True)
plot_standard_normal_distribution()

# %%
# ques 13  Generate random variables and calculate their corresponding probabilities using the binomial distribution

from scipy.stats import binom

def binomial_distribution(n, p, size):
    """
    Generate random variables from a binomial distribution and calculate the probabilities.

    Parameters:
    - n: Number of trials
    - p: Probability of success on each trial
    - size: Number of random variables to generate

    Returns:
    - random_vars: Random variables generated from the binomial distribution
    - probabilities: Corresponding probabilities for each outcome
    """
    random_vars = np.random.binomial(n, p, size)
    k_values = np.arange(0, n+1)
    probabilities = binom.pmf(k_values, n, p)

    return random_vars, probabilities, k_values
n = 10
p = 0.5
size = 1000
random_vars, probabilities, k_values = binomial_distribution(n, p, size)
plt.hist(random_vars, bins=np.arange(0, n+2) - 0.5, edgecolor='black', density=True, alpha=0.7, color='skyblue', label="Generated Data")
plt.plot(k_values, probabilities, 'o', color='red', label="Binomial PMF")
plt.title(f"Binomial Distribution (n={n}, p={p})")
plt.xlabel("Number of Successes (k)")
plt.ylabel("Probability")
plt.legend()
plt.grid(True)
plt.show()

# %%
#ques 14 Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution



def calculate_z_score(x, mean, std_dev):
    """
    Calculate the Z-score for a given data point.

    Parameters:
    - x: The data point
    - mean: The mean of the dataset
    - std_dev: The standard deviation of the dataset

    Returns:
    - z_score: The calculated Z-score
    """
    z_score = (x - mean) / std_dev
    return z_score

def plot_standard_normal_distribution(z_score):
    """
    Plot the standard normal distribution and indicate the position of the Z-score.

    Parameters:
    - z_score: The Z-score to plot on the distribution
    """
    x = np.linspace(-4, 4, 1000)
    pdf = norm.pdf(x, loc=0, scale=1)
    plt.plot(x, pdf, label="Standard Normal Distribution", color='blue', linewidth=2)
    plt.axvline(z_score, color='red', linestyle='dashed', label=f"Z-score = {z_score:.2f}")
    plt.title(f"Standard Normal Distribution and Z-score = {z_score:.2f}")
    plt.xlabel("Value")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.show()
mean = 50
std_dev = 10
x = 60
z_score = calculate_z_score(x, mean, std_dev)
print(f"Z-score for x = {x}: {z_score:.2f}")
plot_standard_normal_distribution(z_score)
probability = norm.cdf(z_score)
print(f"The cumulative probability (CDF) for Z-score = {z_score:.2f} is {probability:.4f}")
# Out:
# Z-score for x = 60: 1.00
# The cumulative probability (CDF) for Z-score = 1.00 is 0.8413

# %%
#ques 15 Implement hypothesis testing using Z-statistics for a sample dataset

import scipy.stats as stats
def z_test(sample_data, population_mean, population_std, sample_size, alpha=0.05):
    """
    Perform a Z-test to determine if the sample mean is significantly different from the population mean.

    Parameters:
    - sample_data: Sample data (array of values)
    - population_mean: Population mean (H0)
    - population_std: Population standard deviation
    - sample_size: Sample size (n)
    - alpha: Significance level (default = 0.05)

    Returns:
    - z_statistic: Calculated Z-statistic
    - p_value: Corresponding p-value
    - decision: Reject or fail to reject the null hypothesis
    """
    sample_mean = np.mean(sample_data)
    z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))
    if p_value <= alpha:
        decision = "Reject the null hypothesis (There is a significant difference)"
    else:
        decision = "Fail to reject the null hypothesis (No significant difference)"

    return z_statistic, p_value, decision
np.random.seed(42)
sample_data = np.random.normal(52, 10, 30)
population_mean = 50
population_std = 10
sample_size = len(sample_data)
z_statistic, p_value, decision = z_test(sample_data, population_mean, population_std, sample_size)
print(f"Z-statistic: {z_statistic:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Decision: {decision}")
# Out:
# Z-statistic: 0.0649
# P-value: 0.9482
# Decision: Fail to reject the null hypothesis (No significant difference)

# %%
# ques 16 Create a confidence interval for a dataset using Python and interpret the result

import numpy as np
import scipy.stats as stats

def confidence_interval(data, confidence_level=0.95):
    """
    Calculate the confidence interval for the mean of the dataset.

    Parameters:
    - data: The sample dataset (array of values)
    - confidence_level: The confidence level (default = 0.95)

    Returns:
    - lower_bound: Lower bound of the confidence interval
    - upper_bound: Upper bound of the confidence interval
    """
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)
    n = len(data)
    sem = sample_std / np.sqrt(n)
    if n > 30:
        critical_value = stats.norm.ppf(1 - (1 - confidence_level) / 2)
    else:
        critical_value = stats.t.ppf(1 - (1 - confidence_level) / 2, df=n-1)
    margin_of_error = critical_value * sem
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound, sample_mean
np.random.seed(42)
sample_data = np.random.normal(100, 15, 50)
confidence_level = 0.95
lower_bound, upper_bound, sample_mean = confidence_interval(sample_data, confidence_level)

print(f"Sample Mean: {sample_mean:.2f}")
print(f"{int(confidence_level * 100)}% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
print("\nInterpretation:")
print(f"The true population mean is estimated to be between {lower_bound:.2f} and {upper_bound:.2f}")
print(f"We are {confidence_level * 100}% confident that the true population mean lies within this range.")
# Out:
# Sample Mean: 96.62
# 95% Confidence Interval: (92.74, 100.50)
#
# Interpretation:
# The true population mean is estimated to be between 92.74 and 100.50
# We are 95.0% confident that the true population mean lies within this range.

# %%
# ques 17 Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean

def confidence_interval(data, confidence_level=0.95):
    """
    Calculate the confidence interval for the mean of the dataset.

    Parameters:
    - data: The sample dataset (array of values)
    - confidence_level: The confidence level (default = 0.95)

    Returns:
    - lower_bound: Lower bound of the confidence interval
    - upper_bound: Upper bound of the confidence interval
    """
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)
    n = len(data)
    sem = sample_std / np.sqrt(n)
    if n > 30:
        critical_value = stats.norm.ppf(1 - (1 - confidence_level) / 2)
    else:
        critical_value = stats.t.ppf(1 - (1 - confidence_level) / 2, df=n-1)
    margin_of_error = critical_value * sem
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound, sample_mean
np.random.seed(42)
true_mean = 50
true_std = 10
sample_size = 100
sample_data = np.random.normal(true_mean, true_std, sample_size)
confidence_level = 0.95
lower_bound, upper_bound, sample_mean = confidence_interval(sample_data, confidence_level)
print(f"Sample Mean: {sample_mean:.2f}")
print(f"{int(confidence_level * 100)}% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
print("\nInterpretation:")
print(f"The true population mean is estimated to be between {lower_bound:.2f} and {upper_bound:.2f}")
print(f"We are {confidence_level * 100}% confident that the true population mean lies within this range.")
# Out:
# Sample Mean: 48.96
# 95% Confidence Interval: (47.18, 50.74)
#
# Interpretation:
# The true population mean is estimated to be between 47.18 and 50.74
# We are 95.0% confident that the true population mean lies within this range.

# %%
#ques 18 Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution

mean = 0
std_dev = 1
x_values = np.linspace(-5, 5, 1000)
pdf_values = stats.norm.pdf(x_values, mean, std_dev)
plt.figure(figsize=(8, 6))
plt.plot(x_values, pdf_values, label=f'Normal Distribution\nmean={mean}, std={std_dev}', color='blue')
plt.title('Probability Density Function (PDF) of a Normal Distribution', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.grid(True)
plt.legend()
plt.show()

# %%
#ques 19  Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution

lambda_poisson = 5
k_values = np.arange(0, 16)
cdf_values = stats.poisson.cdf(k_values, lambda_poisson)
plt.figure(figsize=(8, 6))
plt.plot(k_values, cdf_values, marker='o', linestyle='-', color='blue', label=f'Poisson CDF\nλ={lambda_poisson}')
plt.fill_between(k_values, cdf_values, color='skyblue', alpha=0.4)
plt.title(f'Cumulative Distribution Function (CDF) of Poisson Distribution\nλ = {lambda_poisson}', fontsize=14)
plt.xlabel('k (Number of events)', fontsize=12)
plt.ylabel('Cumulative Probability', fontsize=12)
plt.grid(True)
plt.legend()
plt.show()
for k, cdf in zip(k_values, cdf_values):
    print(f'P(X ≤ {k}) = {cdf:.4f}')
# Out:
# P(X ≤ 0) = 0.0067
# P(X ≤ 1) = 0.0404
# P(X ≤ 2) = 0.1247
# P(X ≤ 3) = 0.2650
# P(X ≤ 4) = 0.4405
# P(X ≤ 5) = 0.6160
# P(X ≤ 6) = 0.7622
# P(X ≤ 7) = 0.8666
# P(X ≤ 8) = 0.9319
# P(X ≤ 9) = 0.9682
# P(X ≤ 10) = 0.9863
# P(X ≤ 11) = 0.9945
# P(X ≤ 12) = 0.9980
# P(X ≤ 13) = 0.9993
# P(X ≤ 14) = 0.9998
# P(X ≤ 15) = 0.9999

# %%
#ques 20  Simulate a random variable using a continuous uniform distribution and calculate its expected value

def simulate_uniform_distribution(a, b, num_samples):
    samples = np.random.uniform(a, b, num_samples)
    expected_value_theoretical = (a + b) / 2
    sample_mean = np.mean(samples)
    return samples, expected_value_theoretical, sample_mean
a = 2
b = 8
num_samples = 10000
samples, expected_value_theoretical, sample_mean = simulate_uniform_distribution(a, b, num_samples)
print(f"Theoretical Expected Value: {expected_value_theoretical:.2f}")
print(f"Empirical Sample Mean (approx. Expected Value): {sample_mean:.2f}")
# Out:
# Theoretical Expected Value: 5.00
# Empirical Sample Mean (approx. Expected Value): 4.97

# %%
# ques 21 Write a Python program to compare the standard deviations of two datasets and visualize the difference

np.random.seed(42)
data1 = np.random.normal(loc=50, scale=5, size=500)
data2 = np.random.normal(loc=50, scale=15, size=500)
std_dev1 = np.std(data1)
std_dev2 = np.std(data2)
print(f"Standard Deviation of Dataset 1: {std_dev1:.2f}")
print(f"Standard Deviation of Dataset 2: {std_dev2:.2f}")
plt.figure(figsize=(10, 6))
plt.hist(data1, bins=30, alpha=0.6, label=f'Dataset 1 (std={std_dev1:.2f})', color='blue', density=True)
plt.hist(data2, bins=30, alpha=0.6, label=f'Dataset 2 (std={std_dev2:.2f})', color='red', density=True)
plt.title('Comparison of Standard Deviations of Two Datasets', fontsize=14)
plt.xlabel('Value', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend()
plt.show()
# Out:
# Standard Deviation of Dataset 1: 4.90
# Standard Deviation of Dataset 2: 14.66

# %%
#ques 22 Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution

import numpy as np
np.random.seed(42)
mean = 50
std_dev = 10
size = 1000
data = np.random.normal(loc=mean, scale=std_dev, size=size)
range_value = np.max(data) - np.min(data)
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
print(f"Range of the dataset: {range_value:.2f}")
print(f"Interquartile Range (IQR) of the dataset: {IQR:.2f}")
# Out:
# Range of the dataset: 70.94
# Interquartile Range (IQR) of the dataset: 12.96

# %%
#ques 23  Implement Z-score normalization on a dataset and visualize its transformation

np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)
mean = np.mean(data)
std_dev = np.std(data)
z_scores = (data - mean) / std_dev
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='orange', edgecolor='black')
plt.title('Original Data (Before Z-score Normalization)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.subplot(1, 2, 2)
plt.hist(z_scores, bins=30, color='purple', edgecolor='black')
plt.title('Normalized Data (After Z-score Normalization)')
plt.xlabel('Z-score')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
print(f"Mean of normalized data: {np.mean(z_scores):.2f}")
print(f"Standard Deviation of normalized data: {np.std(z_scores):.2f}")
# Out:
# Mean of normalized data: -0.00
# Standard Deviation of normalized data: 1.00

# %%
#ques 24  Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

import numpy as np
from scipy.stats import skew, kurtosis

def calculate_skewness_kurtosis(data):
    skewness = skew(data)
    kurt = kurtosis(data)
    return skewness, kurt
np.random.seed(42)
mean = 50
std_dev = 10
size = 1000
data = np.random.normal(loc=mean, scale=std_dev, size=size)
skewness, kurt = calculate_skewness_kurtosis(data)
print(f"Skewness of the dataset: {skewness:.4f}")
print(f"Kurtosis of the dataset: {kurt:.4f}")
# Out:
# Skewness of the dataset: 0.1168
# Kurtosis of the dataset: 0.0662
